# %% [markdown]
# ## Imports

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

from xgboost import XGBClassifier
import sklearn

pd.set_option('display.max_columns', None)
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# ## Functions

# %%
def get_clean_cabin_nums(cabin_nums):
    if isinstance(cabin_nums, float):
        if pd.isna(cabin_nums):
            return []
        else:
            return [cabin_nums]
    elif isinstance(cabin_nums, list):
        if len(cabin_nums) == 0:
            return []
        else:
            return [int(c) for c in cabin_nums if len(c) > 0]
                
def get_cabin_nums(df):
    cabin_nums_list = (
        df['Cabin']
        .str.replace('[a-zA-Z]', '', regex=True)
        .str.strip()
        .str.split(' ')
    )
    
    return cabin_nums_list.apply(get_clean_cabin_nums)

def is_any_cabin_within_range(cabin_nums, low_exc, high_inc):
    cabin_nums = np.array(cabin_nums)
    
    return np.any(
        (cabin_nums > low_exc)
        & (cabin_nums <= high_inc)
    )

def get_has_cabin_number_in_range_onehot(df, bins):
    cabin_nums_list = get_cabin_nums(df)
    
    cabin_number_range_map = {}
    
    for i in range(len(bins) - 1):
        low_exc = bins[i]
        high_inc = bins[i + 1]
        
        cabin_number_range_map[f'has_cabin_number_between_{low_exc + 1}_{high_inc}'] = (
            cabin_nums_list.apply(
                lambda cabin_nums : is_any_cabin_within_range(cabin_nums, low_exc, high_inc)
            )
        )

    return pd.DataFrame.from_dict(cabin_number_range_map)

def get_cabin_letter_onehot(df):
    cabin_letters = {}
    
    for cabin_letter in 'ABCDEFGT':
        cabin_letters[f'is_cabin_letter_' + cabin_letter] = df['Cabin'].fillna('').str.contains(cabin_letter)

    return pd.DataFrame.from_dict(cabin_letters)

def get_input_data(df, mean_age):
    clean_cols = [
        'SibSp',
        'Parch',
        'Fare'
    ]

    # WARNING: ASSUMPTION
    clean_age = df['Age'].fillna(mean_age)
    
    is_male = df['Sex'] == 'male'
    pclass_onehot = pd.get_dummies(df['Pclass'], prefix='Pclass')
    embarked_onehot = pd.get_dummies(df['Embarked'], prefix='Embarked')
    has_cabin = ~df['Cabin'].isna()
    
    num_of_cabins = (
        df['Cabin'].str.split(' ')
        .str.len()
        .fillna(0)
    )
    
    cabin_letters_onehot = get_cabin_letter_onehot(df)
    
    has_cabin_number_in_range_onehot = get_has_cabin_number_in_range_onehot(df, np.arange(0, 151, 10))

    return pd.concat(
        (
            df[clean_cols],
            clean_age.rename('clean_age'),
            is_male.rename('is_male'),
            pclass_onehot,
            embarked_onehot,
            # has_cabin.rename('has_cabin'),
            num_of_cabins.rename('num_of_cabins'),
            cabin_letters_onehot,
            has_cabin_number_in_range_onehot,
        ),
        axis=1
    )

# %% [markdown]
# ## Prepare Data

# %%
df_original = pd.read_csv('/kaggle/input/titanic/train.csv')
df, df_val = sklearn.model_selection.train_test_split(df_original, test_size=0.1, stratify=df_original['Survived'])

df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
df['Survived'].mean()
# Out:
# 0.383270911360799

# %%
df_val['Survived'].mean()
# Out:
# 0.3888888888888889

# %%
mean_age = df['Age'].mean()

input_df = get_input_data(df, mean_age)
input_df_val = get_input_data(df_val, mean_age)
input_df_test = get_input_data(df_test, mean_age)

# %%
input_df.head()
# Out:
#      SibSp  Parch    Fare  clean_age  is_male  Pclass_1  Pclass_2  Pclass_3  \
# 682      0      0  9.2250       20.0     True     False     False      True
# 847      0      0  7.8958       35.0     True     False     False      True
# 103      0      0  8.6542       33.0     True     False     False      True
# 115      0      0  7.9250       21.0     True     False     False      True
# 402      1      0  9.8250       21.0    False     False     False      True
#
#      Embarked_C  Embarked_Q  Embarked_S  num_of_cabins  is_cabin_letter_A  \
# 682       False       False        True            0.0              False
# 847        True       False       False            0.0              False
# 103       False       False        True            0.0              False
# 115       False       False        True            0.0              False
# 402       False       False        True            0.0              False
#
#      is_cabin_letter_B  is_cabin_letter_C  is_cabin_letter_D  \
# 682              False              False              False
# 847              False              False              False
# 103              False              False              False
# 115              False              False              False
# 402              False              False              False
#
#      is_cabin_letter_E  is_cabin_letter_F  is_cabin_letter_G  \
# 682              False              False              False
# 847              False              False              False
# 103              False              False              False
# 115              False              False              False
# 402              False              False              False
#
#      is_cabin_letter_T  has_cabin_number_between_1_10  \
# 682              False                          False
# 847              False                          False
# 103              False                          False
# 115              False                          False
# 402              False                          False
#
#      has_cabin_number_between_11_20  has_cabin_number_between_21_30  \
# 682                           False                           False
# 847                           False                           False
# 103                           False                           False
# 115                           False                           False
# 402                           False                           False
#
#      has_cabin_number_between_31_40  has_cabin_number_between_41_50  \
# 682                           False                           False
# 847                           False                           False
# 103                           False                           False
# 115                           False                           False
# 402                           False                           False
#
#      has_cabin_number_between_51_60  has_cabin_number_between_61_70  \
# 682                           False                           False
# 847                           False                           False
# 103                           False                           False
# 115                           False                           False
# 402                           False                           False
#
#      has_cabin_number_between_71_80  has_cabin_number_between_81_90  \
# 682                           False                           False
# 847                           False                           False
# 103                           False                           False
# 115                           False                           False
# 402                           False                           False
#
#      has_cabin_number_between_91_100  has_cabin_number_between_101_110  \
# 682                            False                             False
# 847                            False                             False
# 103                            False                             False
# 115                            False                             False
# 402                            False                             False
#
#      has_cabin_number_between_111_120  has_cabin_number_between_121_130  \
# 682                             False                             False
# 847                             False                             False
# 103                             False                             False
# 115                             False                             False
# 402                             False                             False
#
#      has_cabin_number_between_131_140  has_cabin_number_between_141_150
# 682                             False                             False
# 847                             False                             False
# 103                             False                             False
# 115                             False                             False
# 402                             False                             False

# %%
input_df.mean()
# Out:
# SibSp                                0.514357
# Parch                                0.372035
# Fare                                32.400987
# clean_age                           29.939003
# is_male                              0.646692
# Pclass_1                             0.249688
# Pclass_2                             0.207241
# Pclass_3                             0.543071
# Embarked_C                           0.196005
# Embarked_Q                           0.082397
# Embarked_S                           0.719101
# num_of_cabins                        0.279650
# is_cabin_letter_A                    0.018727
# is_cabin_letter_B                    0.053683
# is_cabin_letter_C                    0.068664
# is_cabin_letter_D                    0.041199
# is_cabin_letter_E                    0.041199
# is_cabin_letter_F                    0.014981
# is_cabin_letter_G                    0.007491
# is_cabin_letter_T                    0.001248
# has_cabin_number_between_1_10        0.033708
# has_cabin_number_between_11_20       0.023720
# has_cabin_number_between_21_30       0.028714
# has_cabin_number_between_31_40       0.033708
# has_cabin_number_between_41_50       0.026217
# has_cabin_number_between_51_60       0.012484
# has_cabin_number_between_61_70       0.016230
# has_cabin_number_between_71_80       0.012484
# has_cabin_number_between_81_90       0.009988
# has_cabin_number_between_91_100      0.014981
# has_cabin_number_between_101_110     0.011236
# has_cabin_number_between_111_120     0.002497
# has_cabin_number_between_121_130     0.013733
# has_cabin_number_between_131_140     0.000000
# has_cabin_number_between_141_150     0.001248
# dtype: float64

# %%
input_df.describe()
# Out:
#             SibSp       Parch        Fare   clean_age  num_of_cabins
# count  801.000000  801.000000  801.000000  801.000000      801.00000
# mean     0.514357    0.372035   32.400987   29.939003        0.27965
# std      1.063064    0.797757   50.245005   12.931490        0.54470
# min      0.000000    0.000000    0.000000    0.420000        0.00000
# 25%      0.000000    0.000000    7.925000   22.000000        0.00000
# 50%      0.000000    0.000000   14.500000   29.939003        0.00000
# 75%      1.000000    0.000000   31.275000   35.000000        0.00000
# max      8.000000    6.000000  512.329200   80.000000        4.00000

# %%
input_df_test.head()
# Out:
#    SibSp  Parch     Fare  clean_age  is_male  Pclass_1  Pclass_2  Pclass_3  \
# 0      0      0   7.8292       34.5     True     False     False      True
# 1      1      0   7.0000       47.0    False     False     False      True
# 2      0      0   9.6875       62.0     True     False      True     False
# 3      0      0   8.6625       27.0     True     False     False      True
# 4      1      1  12.2875       22.0    False     False     False      True
#
#    Embarked_C  Embarked_Q  Embarked_S  num_of_cabins  is_cabin_letter_A  \
# 0       False        True       False            0.0              False
# 1       False       False        True            0.0              False
# 2       False        True       False            0.0              False
# 3       False       False        True            0.0              False
# 4       False       False        True            0.0              False
#
#    is_cabin_letter_B  is_cabin_letter_C  is_cabin_letter_D  is_cabin_letter_E  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    is_cabin_letter_F  is_cabin_letter_G  is_cabin_letter_T  \
# 0              False              False              False
# 1              False              False              False
# 2              False              False              False
# 3              False              False              False
# 4              False              False              False
#
#    has_cabin_number_between_1_10  has_cabin_number_between_11_20  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    has_cabin_number_between_21_30  has_cabin_number_between_31_40  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    has_cabin_number_between_41_50  has_cabin_number_between_51_60  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    has_cabin_number_between_61_70  has_cabin_number_between_71_80  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    has_cabin_number_between_81_90  has_cabin_number_between_91_100  \
# 0                           False                            False
# 1                           False                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
#    has_cabin_number_between_101_110  has_cabin_number_between_111_120  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    has_cabin_number_between_121_130  has_cabin_number_between_131_140  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    has_cabin_number_between_141_150
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False

# %%
input_df_test.mean()
# Out:
# SibSp                                0.447368
# Parch                                0.392344
# Fare                                35.627188
# clean_age                           30.203958
# is_male                              0.636364
# Pclass_1                             0.255981
# Pclass_2                             0.222488
# Pclass_3                             0.521531
# Embarked_C                           0.244019
# Embarked_Q                           0.110048
# Embarked_S                           0.645933
# num_of_cabins                        0.282297
# is_cabin_letter_A                    0.016746
# is_cabin_letter_B                    0.043062
# is_cabin_letter_C                    0.083732
# is_cabin_letter_D                    0.031100
# is_cabin_letter_E                    0.026316
# is_cabin_letter_F                    0.019139
# is_cabin_letter_G                    0.004785
# is_cabin_letter_T                    0.000000
# has_cabin_number_between_1_10        0.023923
# has_cabin_number_between_11_20       0.014354
# has_cabin_number_between_21_30       0.028708
# has_cabin_number_between_31_40       0.038278
# has_cabin_number_between_41_50       0.023923
# has_cabin_number_between_51_60       0.033493
# has_cabin_number_between_61_70       0.016746
# has_cabin_number_between_71_80       0.014354
# has_cabin_number_between_81_90       0.009569
# has_cabin_number_between_91_100      0.002392
# has_cabin_number_between_101_110     0.009569
# has_cabin_number_between_111_120     0.004785
# has_cabin_number_between_121_130     0.002392
# has_cabin_number_between_131_140     0.002392
# has_cabin_number_between_141_150     0.000000
# dtype: float64

# %%
input_df_test.describe()
# Out:
#             SibSp       Parch        Fare   clean_age  num_of_cabins
# count  418.000000  418.000000  417.000000  418.000000     418.000000
# mean     0.447368    0.392344   35.627188   30.203958       0.282297
# std      0.896760    0.981429   55.907576   12.635256       0.628441
# min      0.000000    0.000000    0.000000    0.170000       0.000000
# 25%      0.000000    0.000000    7.895800   23.000000       0.000000
# 50%      0.000000    0.000000   14.454200   29.939003       0.000000
# 75%      1.000000    0.000000   31.500000   35.750000       0.000000
# max      8.000000    9.000000  512.329200   76.000000       4.000000

# %% [markdown]
# ## Train Model

# %%
bst = XGBClassifier(n_estimators=50, max_depth=5, learning_rate=1, objective='binary:logistic')
bst.fit(input_df, df['Survived'])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## Evaluate Model

# %%
y_true = df_val['Survived']
y_score = bst.predict(input_df_val)

# %%
sklearn.metrics.accuracy_score(y_true, y_score)
# Out:
# 0.8222222222222222

# %%
sklearn.metrics.average_precision_score(y_true, y_score)
# Out:
# 0.6897099069512863

# %%
sklearn.metrics.precision_score(y_true, y_score > 0.5)
# Out:
# 0.8275862068965517

# %%
sklearn.metrics.recall_score(y_true, y_score > 0.5)
# Out:
# 0.6857142857142857

# %% [markdown]
# ## Test

# %%
pred_test = bst.predict(input_df_test)

# %%
submission_df = pd.concat((df_test['PassengerId'], pd.Series(pred_test).rename('Survived')), axis=1)

# %%
submission_df.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.366029
# std     120.810458    0.482295
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
submission_df.to_csv('submission.csv', index=False)

# %% [markdown]
# ## Appendix - EDA

# %%
df.head()
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 682          683         0       3  Olsvigen, Mr. Thor Anderson    male  20.0
# 847          848         0       3           Markoff, Mr. Marin    male  35.0
# 103          104         0       3   Johansson, Mr. Gustaf Joel    male  33.0
# 115          116         0       3        Pekoniemi, Mr. Edvard    male  21.0
# 402          403         0       3     Jussila, Miss. Mari Aina  female  21.0
#
#      SibSp  Parch             Ticket    Fare Cabin Embarked
# 682      0      0               6563  9.2250   NaN        S
# 847      0      0             349213  7.8958   NaN        C
# 103      0      0               7540  8.6542   NaN        S
# 115      0      0  STON/O 2. 3101294  7.9250   NaN        S
# 402      1      0               4137  9.8250   NaN        S

# %%
(~df['Cabin'].isna()).mean()
# Out:
# 0.24344569288389514

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
pd.get_dummies(df['Pclass'], prefix='Pclass').head()
# Out:
#      Pclass_1  Pclass_2  Pclass_3
# 682     False     False      True
# 847     False     False      True
# 103     False     False      True
# 115     False     False      True
# 402     False     False      True

# %%
df['SibSp'].describe()
# Out:
# count    801.000000
# mean       0.514357
# std        1.063064
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
df['Parch'].describe()
# Out:
# count    801.000000
# mean       0.372035
# std        0.797757
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
df['Fare'].describe()
# Out:
# count    801.000000
# mean      32.400987
# std       50.245005
# min        0.000000
# 25%        7.925000
# 50%       14.500000
# 75%       31.275000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'D19', 'C86', 'F4', 'B58 B60', 'A36', 'A14', 'A10', 'C126',
#        'C123', 'D36', 'C101', 'A20', 'C22 C26', 'C128', 'C62 C64',
#        'B96 B98', 'G6', 'E33', 'B28', 'B38', 'B41', 'D6', 'B5', 'B19',
#        'F2', 'B102', 'C70', 'B71', 'C2', 'C92', 'E34', 'B4', 'A6', 'B86',
#        'E24', 'D', 'D33', 'F33', 'E101', 'C125', 'A34', 'B79', 'C103',
#        'C91', 'B94', 'B30', 'C68', 'C95', 'D35', 'C54', 'B39', 'D15',
#        'E44', 'C104', 'E68', 'C45', 'D46', 'B69', 'D17', 'A26', 'C52',
#        'C65', 'F G63', 'E77', 'D37', 'D47', 'C124', 'B77', 'B101', 'E12',
#        'D48', 'C23 C25 C27', 'E63', 'E25', 'C83', 'D7', 'E36', 'A5',
#        'B57 B59 B63 B66', 'C90', 'C118', 'C50', 'B51 B53 B55', 'E10',
#        'D26', 'B49', 'B20', 'D11', 'C32', 'E67', 'C111', 'E121', 'F38',
#        'C93', 'C99', 'B50', 'A16', 'E46', 'D9', 'D56', 'E8', 'F E69',
#        'C30', 'C87', 'E50', 'E58', 'C47', 'B37', 'E31', 'D28', 'D21', 'T',
#        'E17', 'D10 D12', 'C7', 'D45', 'B42', 'E38', 'F G73', 'A31', 'A24',
#        'D49', 'B80', 'B18', 'D20', 'C78', 'E40', 'C46', 'A19', 'B3',
#        'B22', 'C49', 'A23', 'B35', 'B82 B84', 'D30', 'A32', 'B78', 'E49',
#        'A7', 'C106', 'C148', 'C85', 'D50', 'B73'], dtype=object)

# %%
num_of_cabins = df['Cabin'].str.split(' ').str.len()

# %%
num_of_cabins.describe()
# Out:
# count    195.000000
# mean       1.148718
# std        0.469081
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: Cabin, dtype: float64

# %%
num_of_cabins.fillna(0).describe()
# Out:
# count    801.00000
# mean       0.27965
# std        0.54470
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        4.00000
# Name: Cabin, dtype: float64

# %%
_df = df[df['Cabin'].isna()]

# %%
_df.head()
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 682          683         0       3  Olsvigen, Mr. Thor Anderson    male  20.0
# 847          848         0       3           Markoff, Mr. Marin    male  35.0
# 103          104         0       3   Johansson, Mr. Gustaf Joel    male  33.0
# 115          116         0       3        Pekoniemi, Mr. Edvard    male  21.0
# 402          403         0       3     Jussila, Miss. Mari Aina  female  21.0
#
#      SibSp  Parch             Ticket    Fare Cabin Embarked
# 682      0      0               6563  9.2250   NaN        S
# 847      0      0             349213  7.8958   NaN        C
# 103      0      0               7540  8.6542   NaN        S
# 115      0      0  STON/O 2. 3101294  7.9250   NaN        S
# 402      1      0               4137  9.8250   NaN        S

# %%
df['Cabin'].str.replace('\d', '', regex=True).unique()
# Out:
# array([nan, 'D', 'C', 'F', 'B B', 'A', 'C C', 'G', 'E', 'B', 'F G',
#        'C C C', 'B B B B', 'B B B', 'F E', 'T', 'D D'], dtype=object)

# %%
df_test['Cabin'].str.replace('\d', '', regex=True).unique()
# Out:
# array([nan, 'B', 'E', 'B B B B', 'A', 'C', 'D', 'C C C', 'F G', 'C C',
#        'F', 'G', 'B B', 'F E', 'B B B', 'D D', 'E E'], dtype=object)

# %%
a = [1, 3, 5]
np.any((np.array(a) <= 1) & (np.array(a) > 0))
# Out:
# True

# %%
get_cabin_nums(df).explode().fillna(-1).describe()
# Out:
# /tmp/ipykernel_406/588040489.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   get_cabin_nums(df).explode().fillna(-1).describe()
# count    827.000000
# mean      12.431681
# std       28.678752
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        5.000000
# max      148.000000
# Name: Cabin, dtype: float64

# %%
get_cabin_nums(df_test).explode().fillna(-1).describe()
# Out:
# /tmp/ipykernel_406/823614993.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   get_cabin_nums(df_test).explode().fillna(-1).describe()
# count    442.000000
# mean      11.572398
# std       25.794504
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        4.000000
# max      132.000000
# Name: Cabin, dtype: float64

# %%
pd.get_dummies(df['Embarked'], prefix='Embarked').head()
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 682       False       False        True
# 847        True       False       False
# 103       False       False        True
# 115       False       False        True
# 402       False       False        True

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            159
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          606
# Embarked         2
# dtype: int64

# %%
df[df['Age'].isna()].head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 547          548         1       2            Padro y Manent, Mr. Julian
# 643          644         1       3                       Foo, Mr. Choong
# 47            48         1       3             O'Driscoll, Miss. Bridget
# 48            49         0       3                   Samaan, Mr. Youssef
# 490          491         0       3  Hagland, Mr. Konrad Mathias Reiersen
#
#         Sex  Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 547    male  NaN      0      0  SC/PARIS 2146  13.8625   NaN        C
# 643    male  NaN      0      0           1601  56.4958   NaN        S
# 47   female  NaN      0      0          14311   7.7500   NaN        Q
# 48     male  NaN      2      0           2662  21.6792   NaN        C
# 490    male  NaN      1      0          65304  19.9667   NaN        S

# %%
df_test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_test[df_test['Age'].isna()].head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 10          902       3                                   Ilieff, Mr. Ylio
# 22          914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29          921       3                                  Samaan, Mr. Elias
# 33          925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36          928       3                                Roth, Miss. Sarah A
#
#        Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 10    male  NaN      0      0      349220   7.8958   NaN        S
# 22  female  NaN      0      0    PC 17598  31.6833   NaN        S
# 29    male  NaN      2      0        2662  21.6792   NaN        C
# 33  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
# 36  female  NaN      0      0      342712   8.0500   NaN        S

# %%
df[df['Fare'] == 0].head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
# 277          278         0       2      Parkes, Mr. Francis "Frank"  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 263          264         0       1            Harrison, Mr. William  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 806  39.0      0      0  112050   0.0   A36        S
# 822  38.0      0      0   19972   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 815   NaN      0      0  112058   0.0  B102        S
# 263  40.0      0      0  112059   0.0   B94        S
